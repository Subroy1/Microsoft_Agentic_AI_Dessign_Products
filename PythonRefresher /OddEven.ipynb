# %% [markdown]
# Take an input from user and print odd or even

# %%
#Input Method
num = int(input("Enter a number: "))

#1st condition
if num >= 0:
    if num == 0:
        print("The number is Zero")
    elif num % 2 == 0:
        print("The number is Positive and Even")
    else:
        print("The number is Positive and Odd")
else:
    if num % 2 == 0:
        print("The number is Negative and Even")
    else:
        print("The number is Negative and Odd")
# Out:
# Enter a number: 10
# The number is Positive and Even

# %%
a=10
b=20
print("First no. is ",a)
# Out:
# First no. is  10

# %%
# Immutable collection
# Create an example of a list of numbers to demonstrate negative index retrieval
numbers = [10, 20, 30, 40, 50]

# Retrieve the last element using a negative index
last_element = numbers[:-2]
#print(last_element)
# Out:
# [10, 20, 30]

# %%
# prepare a list of characters
characters = ['a','b','f','D','d','G','h']
print(characters[:-2])
# slicing example
print(characters[-2:7])
print(characters[2:-3])
characters[-2:]
# Out:
# ['a', 'b', 'f', 'D', 'd']
# ['G', 'h']
# ['f', 'D']
# ['G', 'h']

# %%
numbers[1]=25
print(numbers)
numbers[-4]=-14
print(numbers)
# Out:
# [10, 25, 30, 40, 50]
# [10, -14, 30, 40, 50]

# %%
numbers.append('A')
print(numbers)
numbers.pop(-4)
numbers
# Out:
# [10, -14, 90, 34, 90, 'A', 'A']
# [10, -14, 90, 90, 'A', 'A']

# %%
numbers.insert(4,34)
numbers
# Out:
# [10, -14, 90, 90, 34, 90]

# %%
#numbers.insert(2,60)
numbers.remove(90) # removes the first occurence of the number
numbers
# Out:
# [-14, 60, 40, 90, 'A', 'A']

# %%
charremoved = numbers.pop()
# print the popped element
print("Popped element:", charremoved)
# print the updated list
numbers
# Out:
# Popped element: A
# [-14, 60, 40, 90]

# %%
print("length of the list is", len(numbers))
# Out:
# length of the list is 4

# %%
# add some more numbers to the list
numbers.append(40)
numbers.append(60)
numbers.append(87)
numbers.append(34)
numbers
# Out:
# [-14, 60, 40, 90, 40, 60, 87, 34]

# %%
poppednum = numbers.pop(4)
poppednum
# Out:
# 40

# %%
print(numbers)
del numbers[2]
print(numbers)
# Out:
# [-14, 60, 90, 60, 87, 34]
# [-14, 60, 60, 87, 34]

# %% [markdown]
# Indices work like below [start_index:end_index]
#
# variable[start_index:end_index:2] # this indicates from start ind to end index  (in this case the complete variable list , and skip 2 items)

# %%
# Membership
print(numbers)
print ("Is 30 present ", 30 in numbers)
# SOrting  ascending
sort_num = numbers.sort()
print(sort_num)

# Reverse
numbers.reverse()
numbers
# Out:
# [-14, 34, 60, 60, 87]
# Is 30 present  False
# None
# [87, 60, 60, 34, -14]

# %%
print(characters)
characters.sort()
characters
# Out:
# ['a', 'b', 'f', 'D', 'd', 'G', 'h']
# ['D', 'G', 'a', 'b', 'd', 'f', 'h']
